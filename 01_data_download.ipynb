# %%
import geopandas as gpd

roi = gpd.read_file("roi.geojson")
roi_bbox = roi.total_bounds  # [minx, miny, maxx, maxy]
roi_bbox
# Out:
# array([75. , 28. , 77.8, 31.5])

# %%
pip install pystac_client
# Out:
# Requirement already satisfied: pystac_client in c:\users\riya\appdata\local\programs\python\python312\lib\site-packages (0.9.0)
# Requirement already satisfied: requests>=2.28.2 in c:\users\riya\appdata\local\programs\python\python312\lib\site-packages (from pystac_client) (2.32.3)
# Requirement already satisfied: pystac>=1.10.0 in c:\users\riya\appdata\local\programs\python\python312\lib\site-packages (from pystac[validation]>=1.10.0->pystac_client) (1.14.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\riya\appdata\local\programs\python\python312\lib\site-packages (from pystac_client) (2.9.0.post0)
# Requirement already satisfied: jsonschema~=4.18 in c:\users\riya\appdata\local\programs\python\python312\lib\site-packages (from pystac[validation]>=1.10.0->pystac_client) (4.22.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\riya\appdata\local\programs\python\python312\lib\site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac_client) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\riya\appdata\local\programs\python\python312\lib\site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac_client) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\riya\appdata\local\programs\python\python312\lib\site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac_client) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\riya\appdata\local\programs\python\python312\lib\site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac_client) (0.18.0)
# Requirement already satisfied: six>=1.5 in c:\users\riya\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pystac_client) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\riya\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.28.2->pystac_client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\riya\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.28.2->pystac_client) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\riya\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.28.2->pystac_client) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\riya\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.28.2->pystac_client) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~andas (C:\Users\RIYA\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\RIYA\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\RIYA\AppData\Local\Programs\Python\Python312\Lib\site-packages)

# %%
from pystac_client import Client
import datetime

catalog = Client.open("https://earth-search.aws.element84.com/v1")

# Date range for Date 1 (Feb 2023)
date1_range = "2023-02-05/2023-02-25"

search_s2_d1 = catalog.search(
    collections=["sentinel-2-l2a"],
    bbox=roi_bbox.tolist(),
    datetime=date1_range,
    query={"eo:cloud_cover": {"lt": 30}}
)

items_s2_d1 = list(search_s2_d1.get_items())
len(items_s2_d1)
# Out:
# C:\Users\RIYA\AppData\Local\Programs\Python\Python312\Lib\site-packages\pystac_client\item_search.py:925: FutureWarning: get_items() is deprecated, use items() instead
#   warnings.warn(
# 107

# %%
for item in items_s2_d1[:5]:
    print(item.id, item.properties["eo:cloud_cover"])
# Out:
# S2A_43RGM_20230225_0_L2A 0.001347
# S2B_43REL_20230223_0_L2A 0.001108
# S2B_43RFL_20230223_0_L2A 0.000226
# S2B_43RGL_20230223_0_L2A 5e-05
# S2B_43RFM_20230223_0_L2A 0.000571

# %%
date2_range = "2023-04-05/2023-04-25"

search_s2_d2 = catalog.search(
    collections=["sentinel-2-l2a"],
    bbox=roi_bbox.tolist(),
    datetime=date2_range,
    query={"eo:cloud_cover": {"lt": 30}}
)

items_s2_d2 = list(search_s2_d2.get_items())

for item in items_s2_d2[:5]:
    print(item.id, item.properties["eo:cloud_cover"])
# Out:
# S2B_43RFL_20230424_0_L2A 6.387484
# S2B_43RFM_20230424_0_L2A 12.483489
# S2B_43REN_20230424_0_L2A 3.825745
# S2B_43REP_20230424_0_L2A 29.695684
# S2A_43RDL_20230422_0_L2A 0.047943

# %% [markdown]
# Only required spectral bands (Red, NIR) and the Scene Classification Layer were downloaded to optimize storage and preprocessing efficiency.

# %%
import os
import requests
from tqdm import tqdm
from pystac_client import Client

# %%
def download_file(url, out_path):
    response = requests.get(url, stream=True)
    response.raise_for_status()

    total = int(response.headers.get("content-length", 0))
    with open(out_path, "wb") as f, tqdm(
        desc=os.path.basename(out_path),
        total=total,
        unit="B",
        unit_scale=True,
        unit_divisor=1024,
    ) as bar:
        for chunk in response.iter_content(chunk_size=8192):
            if chunk:
                f.write(chunk)
                bar.update(len(chunk))

# %%
catalog = Client.open("https://earth-search.aws.element84.com/v1")

# %%
scene_date1 = "S2B_43RGL_20230223_0_L2A"  # Feb (early season)
scene_date2 = "S2A_43RDL_20230422_0_L2A"  # Apr (peak season)

scenes = {
    "date1": scene_date1,
    "date2": scene_date2
}

# %%
bands = {
    "red": "B04.jp2",   # Red band (10m)
    "nir": "B08.jp2",   # NIR band (10m)
    "scl": "SCL.jp2"    # Scene Classification Layer (20m)
}

# %%
base_dir = "data/sentinal2"
os.makedirs(base_dir, exist_ok=True)

# %%
for label, scene_id in scenes.items():
    print(f"\nProcessing {scene_id}")

    search = catalog.search(
        collections=["sentinel-2-l2a"],
        ids=[scene_id]
    )

    item = list(search.get_items())[0]

    out_dir = os.path.join(base_dir, label)
    os.makedirs(out_dir, exist_ok=True)

    for asset_key, filename in bands.items():
        asset = item.assets.get(asset_key)

        if asset is None:
            print(f"❌ {asset_key} not found — skipping")
            continue

        out_path = os.path.join(out_dir, filename)

        if os.path.exists(out_path):
            print(f"✔ {filename} already exists — skipping")
            continue

        print(f"⬇ Downloading {asset_key} → {filename}")
        download_file(asset.href, out_path)
# Out:
# Processing S2B_43RGL_20230223_0_L2A
# ⬇ Downloading red → B04.jp2
# B04.jp2: 100%|██████████████████████████████████████████████████████████████████████| 215M/215M [01:43<00:00, 2.17MB/s]
# ⬇ Downloading nir → B08.jp2
# B08.jp2: 100%|██████████████████████████████████████████████████████████████████████| 228M/228M [02:03<00:00, 1.93MB/s]
# ⬇ Downloading scl → SCL.jp2
# SCL.jp2: 100%|████████████████████████████████████████████████████████████████████| 3.20M/3.20M [00:02<00:00, 1.25MB/s]
# Processing S2A_43RDL_20230422_0_L2A
# ⬇ Downloading red → B04.jp2
# B04.jp2: 100%|██████████████████████████████████████████████████████████████████████| 228M/228M [01:20<00:00, 2.98MB/s]
# ⬇ Downloading nir → B08.jp2
# B08.jp2: 100%|██████████████████████████████████████████████████████████████████████| 199M/199M [01:10<00:00, 2.95MB/s]
# ⬇ Downloading scl → SCL.jp2
# SCL.jp2: 100%|███████████████████████████████████████████████████████████████████████| 349k/349k [00:01<00:00, 241kB/s]
